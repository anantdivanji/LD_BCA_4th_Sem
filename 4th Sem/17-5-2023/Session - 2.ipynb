# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('titanic.csv')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
len(data)
# Out:
# 891

# %%
data.shape
# Out:
# (891, 15)

# %% [markdown]
# ## Check how many people survived and how many did not survive?

# %%
data[data['survived'] == 0]['survived'].count()
# Out:
# 549

# %%
data[data['survived'] == 1]['survived'].count()
# Out:
# 342

# %%
data['survived'].value_counts(normalize = True) * 100
# Out:
# 0    61.616162
# 1    38.383838
# Name: survived, dtype: float64

# %% [markdown]
# ## Proportion of men and women survived?

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
survived_data = data[data['survived'] == 1]
survived_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
survived_data['sex'].value_counts(normalize = True) * 100
# Out:
# female    68.128655
# male      31.871345
# Name: sex, dtype: float64

# %% [markdown]
# ## Dropping the columns from the data

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
## data = data.drop('alive', axis = 1)

data.drop('alive', axis = 1, inplace = True)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alone
# 0    man        True  NaN  Southampton  False
# 1  woman       False    C    Cherbourg  False
# 2  woman       False  NaN  Southampton   True
# 3  woman       False    C  Southampton  False
# 4    man        True  NaN  Southampton   True

# %%
data = pd.read_csv('titanic.csv')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.drop('alive', axis = 1, inplace = True)
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town  alone
# 0    man        True  NaN  Southampton  False
# 1  woman       False    C    Cherbourg  False
# 2  woman       False  NaN  Southampton   True
# 3  woman       False    C  Southampton  False
# 4    man        True  NaN  Southampton   True

# %%
data.drop(['who', 'adult_male'], axis = 1, inplace = True)
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third  NaN
# 1         1       1  female  38.0      1      0  71.2833        C  First    C
# 2         1       3  female  26.0      0      0   7.9250        S  Third  NaN
# 3         1       1  female  35.0      1      0  53.1000        S  First    C
# 4         0       3    male  35.0      0      0   8.0500        S  Third  NaN
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True

# %% [markdown]
# ## Creating new column in the data

# %%
data['new_column'] = data['fare'] * 2
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third  NaN
# 1         1       1  female  38.0      1      0  71.2833        C  First    C
# 2         1       3  female  26.0      0      0   7.9250        S  Third  NaN
# 3         1       1  female  35.0      1      0  53.1000        S  First    C
# 4         0       3    male  35.0      0      0   8.0500        S  Third  NaN
#
#    embark_town  alone  new_column
# 0  Southampton  False     14.5000
# 1    Cherbourg  False    142.5666
# 2  Southampton   True     15.8500
# 3  Southampton  False    106.2000
# 4  Southampton   True     16.1000

# %% [markdown]
# ## Salary data

# %%
data = pd.read_csv('Salaries.csv')
data.head()
# Out:
# C:\Users\AMANT\AppData\Local\Temp\ipykernel_9512\1750936876.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %%
data.shape
# Out:
# (148654, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
data['BasePay'].unique()
# Out:
# array([167411.18, 155966.02, 212739.13, ..., '6.04', '15.50',
#        'Not Provided'], dtype=object)

# %%
data['BasePay'] = data['BasePay'].str.replace('Not Provided', '0')
data['BasePay'].unique()
# Out:
# array([nan, '60618.25', '68712.00', ..., '6.04', '15.50', '0'],
#       dtype=object)

# %%
data['BasePay'] = data['BasePay'].astype('float')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           17582 non-null   float64
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 14.7+ MB

# %%
data['OvertimePay'] = data['OvertimePay'].str.replace('Not Provided', '0')
data['OtherPay'] = data['OtherPay'].str.replace('Not Provided', '0')
data['Benefits'] = data['Benefits'].str.replace('Not Provided', '0')
data[['OvertimePay', 'OtherPay', 'Benefits']] = data[['OvertimePay', 'OtherPay', 'Benefits']].astype('float')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           17582 non-null   float64
#  4   OvertimePay       17582 non-null   float64
#  5   OtherPay          17582 non-null   float64
#  6   Benefits          17582 non-null   float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
#  13  OvertimPay        17582 non-null   object
# dtypes: float64(7), int64(2), object(5)
# memory usage: 15.9+ MB

# %%
data.describe()
# Out:
#                   Id       BasePay   OvertimePay      OtherPay      Benefits  \
# count  148654.000000  17582.000000  17582.000000  17582.000000  17582.000000
# mean    74327.500000  29219.866678    951.343025   1237.566086  11467.580138
# std     42912.857795  22187.012035   2377.435250   3380.342660  11219.059964
# min         1.000000      0.000000      0.000000   -618.130000    -13.800000
# 25%     37164.250000   7797.152500      0.000000      0.000000    148.370000
# 50%     74327.500000  25336.765000      0.000000    179.955000   7844.140000
# 75%    111490.750000  51515.000000    729.677500   1084.032500  24394.542500
# max    148654.000000  92945.870000  28853.640000  89152.010000  36581.690000
#
#             TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000     148654.000000  148654.000000    0.0
# mean    74768.321972      93692.554811    2012.522643    NaN
# std     50517.005274      62793.533483       1.117538    NaN
# ...

# %%
data = pd.read_csv('titanic.csv')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Sort the data by fare column

# %%
data.sort_values('fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
# ...

# %%
data.sort_values('fare', ascending = False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 732         0       2    male   NaN      0      0    0.0000        S  Second
# 674         0       2    male   NaN      0      0    0.0000        S  Second
#
# ...

# %% [markdown]
# ## Selecting only numerical columns from the data

# %%
data.select_dtypes(['int','float'])
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %% [markdown]
# ## Selecting object column from the data

# %%
data.select_dtypes('object')
# Out:
#         sex embarked   class    who deck  embark_town alive
# 0      male        S   Third    man  NaN  Southampton    no
# 1    female        C   First  woman    C    Cherbourg   yes
# 2    female        S   Third  woman  NaN  Southampton   yes
# 3    female        S   First  woman    C  Southampton   yes
# 4      male        S   Third    man  NaN  Southampton    no
# ..      ...      ...     ...    ...  ...          ...   ...
# 886    male        S  Second    man  NaN  Southampton    no
# 887  female        S   First  woman    B  Southampton   yes
# 888  female        S   Third  woman  NaN  Southampton    no
# 889    male        C   First    man    C    Cherbourg   yes
# 890    male        Q   Third    man  NaN   Queenstown    no
#
# [891 rows x 7 columns]

# %%
data['class'].head()
# Out:
# 0    Third
# 1    First
# 2    Third
# 3    First
# 4    Third
# Name: class, dtype: object

# %%
pd.get_dummies(data['class'])
# Out:
#      First  Second  Third
# 0        0       0      1
# 1        1       0      0
# 2        0       0      1
# 3        1       0      0
# 4        0       0      1
# ..     ...     ...    ...
# 886      0       1      0
# 887      1       0      0
# 888      0       0      1
# 889      1       0      0
# 890      0       0      1
#
# [891 rows x 3 columns]

# %%
pd.get_dummies(data['sex'], drop_first = True)
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %% [markdown]
# ## Group by

# %%
data.groupby('sex')['survived'].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
data.groupby('sex').get_group('male')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.groupby('sex').get_group('female')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Calculate the average fare for women and men passengers

# %%
data.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
data.groupby('sex')['fare'].agg(['mean', 'median'])
# Out:
#              mean  median
# sex
# female  44.479818    23.0
# male    25.523893    10.5

# %% [markdown]
# ## Calculate the total fare by each class

# %%
data.groupby('class')['fare'].sum()
# Out:
# class
# First     18177.4125
# Second     3801.8417
# Third      6714.6951
# Name: fare, dtype: float64

# %% [markdown]
# ## Univariate Analysis

# %%
data['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = data['survived'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(y = data['survived'])
# Out:
# <Axes: xlabel='count', ylabel='survived'>

# %% [markdown]
# ## Calculate the count of male and female passenger survived

# %%
data[data['survived'] == 1].groupby('sex')['survived'].count()


#data.groupby('sex')['survived'].count()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
sns.countplot(x = data['survived'], hue = data['sex'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
dic = {0 : 'Not Survived', 1 : 'Survived'}
data['survived'].replace(dic, inplace = True)
data.head()
# Out:
#        survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0  Not Survived       3    male  22.0      1      0   7.2500        S  Third
# 1      Survived       1  female  38.0      1      0  71.2833        C  First
# 2      Survived       3  female  26.0      0      0   7.9250        S  Third
# 3      Survived       1  female  35.0      1      0  53.1000        S  First
# 4  Not Survived       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x = data['survived'], hue = data['sex'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.histplot(x = data['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
 sns.kdeplot(x = data['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Density'>
