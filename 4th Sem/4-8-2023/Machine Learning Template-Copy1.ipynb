# %% [markdown]
# # Step 1 : Import all the standard libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2 : Loading the dataset
# ### Defining Problem Statement
# ### Identifying independent and target variables

# %%
dic = {
    'Yr of Exp' : [2, 4, 5, 7, 8],
    'Salary' : [35000, 50000, 65000, 80000, 95000]
}
dic
# Out:
# {'Yr of Exp': [2, 4, 5, 7, 8], 'Salary': [35000, 50000, 65000, 80000, 95000]}

# %%
data = pd.DataFrame(dic)
data
# Out:
#    Yr of Exp  Salary
# 0          2   35000
# 1          4   50000
# 2          5   65000
# 3          7   80000
# 4          8   95000

# %% [markdown]
# # Step 3 : Data Cleaning, Data Preprocessing

# %%
sns.regplot(x = data['Yr of Exp'], y = data['Salary'])
# Out:
# <Axes: xlabel='Yr of Exp', ylabel='Salary'>

# %% [markdown]
# # Step 4 : Seperate X(Independent Variable) and y(Dependent Variable)

# %%
X = data.drop('Salary', axis = 1)
y = data['Salary']

# %% [markdown]
# # Step 5 : Divide the data into train set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# # Step 6 : Fit ML model on X_train and y_train

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 7 : Perform predictions on X_test

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([62527.47252747])

# %% [markdown]
# # Step 8 : Performance Evaluation

# %%
lr.coef_
# Out:
# array([9890.10989011])

# %%
lr.intercept_
# Out:
# 13076.923076923056

# %%
lr.predict([[16]])
# Out:
# array([171318.68131868])
